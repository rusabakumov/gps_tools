# %%
from gpstools import viz
from gpstools.parser import *
from gpstools.track.track import *
from gpstools.track.utils import build_sparse_track
from gpstools.track.activity_detection import *
from gpstools.track.normalization import *
from gpstools.ss_analysis.ss_analysis_graph import SSAnalysisGraph
import os

# %%
PATH_TO_TRACKS='data/medved3/'
REFERENCE_TRACK='abakumov_su1.gpx'
TRACK_NAME='medved3_w2'
TRACK_TITLE='Медведь 17.03'

SPEED_PARAMS = TrackSpeedParams(use_provided_speed=True, smoothing_1hz=1, smoothing_10hz=1)
ACTIVITY_DETECTION_PARAMS = ActivityDetectionParams(
    distance_eps=0.00005,
    segment_max_allow_pause=1,
    segment_min_duration=100
)

# %%
# Loading and processing reference

# TODO select track type based on file extension
track = load_track(os.path.join(PATH_TO_TRACKS, REFERENCE_TRACK))
#track.print_stats()

ref_segs = get_activity_segments_for_track(track)
# for seg in ref_segs:
#     seg.print_stats()

track = track.crop_to_activity_segment(ref_segs[0], 'ref')
#track.print_stats()

#viz.generate_reference_selection_graph([track])

track = track.crop_to_point_idx(4187)
#track.print_stats()

reference_track = build_sparse_track(track, distance_threshold=0.002)
reference_track.print_stats()



# reference_track = ReferenceTrack(track)
# Out:
# Processing file data/medved3/abakumov_su1.gpx
# Parsing Harry's LapTimer - www.gps-laptimer.de gpx track
# Looks that track has incorrect milliseconds presicion format (i.e written by Harry's Lap Timer). Fixing
# Load track abakumov_su1 with 5163 points
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Track ref
# Start time: 2019-03-17 08:40:02.900000
# End time: 2019-03-17 08:47:01.900000
# Total time: 0:06:59
# Total distance travelled: 8.128 km
# Average speed: 69.84 kph
# Max speed: 126.02 kph
# Average speed value: 77.46 kph

# %%
# # For processing individual tracks and finding bugs

# ACTIVITY_DETECTION_PARAMS_2 = ActivityDetectionParams(
#     distance_eps=0.00005,
#     segment_max_allow_pause=1,
#     segment_min_duration=100
# )

# # track = load_track('data/medved3/kolcov_su1.csv')
# # # track.print_stats()
# # segs = get_activity_segments_for_track(track, ACTIVITY_DETECTION_PARAMS_2)
# # # for seg in segs:
# # #     seg.print_stats()
    
# # track = track.crop_to_activity_segment(segs[2], 'kolcov_su1')
# # track.print_stats()

# # # Test comparision for this track only
# # comparison = SSAnalysisGraph([track], reference_track, point_distance_threshold_km=0.01)
# # comparison.print_stats()

# # viz.plot_distance_speed_graph(comparison.tracks)
# # viz.plot_distance_speed_graph_aligned(comparison.aligned_tracks)

# #viz.plot_distance_speed_graph([track])
# #viz.generate_tracks_map([track])


# SPEED_PARAMS_1 = TrackSpeedParams(use_provided_speed=True, smoothing_1hz=1, smoothing_10hz=3)
# SPEED_PARAMS_2 = TrackSpeedParams(use_provided_speed=True, smoothing_1hz=1, smoothing_10hz=1)
# SPEED_PARAMS_3 = TrackSpeedParams(use_provided_speed=False, smoothing_1hz=1, smoothing_10hz=3)
# SPEED_PARAMS_4 = TrackSpeedParams(use_provided_speed=False, smoothing_1hz=1, smoothing_10hz=1)

# track = load_track('data/medved3/melnikov_su3.csv')
# # track.print_stats()
# segs = get_activity_segments_for_track(track, ACTIVITY_DETECTION_PARAMS_2)
# for seg in segs:
#     seg.print_stats()

# track = track.crop_to_activity_segment(segs[0], 'su1')
# track.print_stats()
    
# track_1 = Track(name=track.name, points=track.points, speed_params=SPEED_PARAMS_1, norm_params=None)
# track_2 = Track(name=track.name, points=track.points, speed_params=SPEED_PARAMS_2, norm_params=None)
# track_3 = Track(name=track.name, points=track.points, speed_params=SPEED_PARAMS_3, norm_params=None)
# track_4 = Track(name=track.name, points=track.points, speed_params=SPEED_PARAMS_4, norm_params=None)

# #viz.plot_distance_speed_graph([track_1, track_2, track_3, track_4])
    
    
# viz.generate_reference_selection_graph([track_1, track_2, track_3, track_4])    

# # Test comparision for this track only
# # comparison = SSAnalysisGraph([track_1, track_2, track_3, track_4], reference_track, point_distance_threshold_km=0.01)
# # comparison.print_stats()

# # comparison.build_comparison_graph('speed_params_test_1', TRACK_TITLE)

# # viz.plot_distance_speed_graph(comparison.tracks)
# # viz.plot_distance_speed_graph_aligned(comparison.aligned_tracks)

# %%
# Loading all tracks

tracks = load_tracks_in_path(PATH_TO_TRACKS)
for track in tracks:
    track.print_stats()
# Out:
# Processing file data/medved3/donchenko_su2.csv
# Load racebox track data/medved3/donchenko_su2.csv with 27896 points
# Load track donchenko_su2 with 27896 points
# Using built-in speed
# Processing file data/medved3/abakumov_su1.gpx
# Parsing Harry's LapTimer - www.gps-laptimer.de gpx track
# Looks that track has incorrect milliseconds presicion format (i.e written by Harry's Lap Timer). Fixing
# Load track abakumov_su1 with 5163 points
# Using built-in speed
# Processing file data/medved3/abakumov_su3.gpx
# Parsing Harry's LapTimer - www.gps-laptimer.de gpx track
# Looks that track has incorrect milliseconds presicion format (i.e written by Harry's Lap Timer). Fixing
# Load track abakumov_su3 with 6022 points
# Using built-in speed
# Processing file data/medved3/abakumov_su2.gpx
# Parsing Harry's LapTimer - www.gps-laptimer.de gpx track
# Looks that track has incorrect milliseconds presicion format (i.e written by Harry's Lap Timer). Fixing
# Load track abakumov_su2 with 5336 points
# Using built-in speed
# Processing file data/medved3/kolcov_su1.csv
# Load racebox track data/medved3/kolcov_su1.csv with 36054 points
# Load track kolcov_su1 with 36054 points
# Using built-in speed
# Processing file data/medved3/melnikov_su3.csv
# Load racebox track data/medved3/melnikov_su3.csv with 36823 points
# Load track melnikov_su3 with 36823 points
# Using built-in speed
# Load 6 tracks:
# donchenko_su2
# abakumov_su1
# abakumov_su3
# abakumov_su2
# kolcov_su1
# melnikov_su3
# Track donchenko_su2
# Start time: 2019-03-20 13:19:13.270000
# End time: 2019-03-20 13:48:03.590000
# Total time: 0:28:50.320000
# Total distance travelled: 7238.807 km
# Average speed: 15060.63 kph
# Max speed: 130.57 kph
# Average speed value: 22.07 kph
#
#
# Track abakumov_su1
# Start time: 2019-03-17 08:38:43
# End time: 2019-03-17 08:47:30.600000
# Total time: 0:08:47.600000
# Total distance travelled: 8.463 km
# Average speed: 57.75 kph
# Max speed: 126.02 kph
# Average speed value: 58.41 kph
#
#
# Track abakumov_su3
# Start time: 2019-03-17 11:34:50.100000
# End time: 2019-03-17 11:44:56.400000
# Total time: 0:10:06.300000
# Total distance travelled: 8.505 km
# Average speed: 50.50 kph
# Max speed: 121.86 kph
# Average speed value: 50.06 kph
#
#
# Track abakumov_su2
# Start time: 2019-03-17 10:29:43.600000
# End time: 2019-03-17 10:38:44.900000
# Total time: 0:09:01.300000
# Total distance travelled: 8.515 km
# Average speed: 56.63 kph
# Max speed: 127.16 kph
# Average speed value: 56.04 kph
#
#
# Track kolcov_su1
# Start time: 2019-03-20 11:17:53.450000
# End time: 2019-03-20 11:55:09.590000
# Total time: 0:37:16.140000
# Total distance travelled: 65063.828 km
# Average speed: 104747.37 kph
# Max speed: 125.53 kph
# Average speed value: 16.83 kph
#
#
# Track melnikov_su3
# Start time: 2019-03-20 14:12:33.860000
# End time: 2019-03-20 14:50:42.460000
# Total time: 0:38:08.600000
# Total distance travelled: 10.595 km
# Average speed: 16.67 kph
# Max speed: 129.10 kph
# Average speed value: 16.44 kph

# %%
comparison = SSAnalysisGraph(tracks, reference_track, speed_params=SPEED_PARAMS, activity_detection_params=ACTIVITY_DETECTION_PARAMS, point_distance_threshold_km=0.01)
print(reference_track.len)
comparison.print_stats()
# Out:
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Using built-in speed
# Found 5 tracks out of 6 initial tracks
# Using built-in speed
# Done dist alignment for track donchenko_su2, 926 points are off the track
# Using built-in speed
# Done dist alignment for track abakumov_su1, 0 points are off the track
# Using built-in speed
# Done dist alignment for track abakumov_su2, 182 points are off the track
# Using built-in speed
# Done dist alignment for track kolcov_su1, 3519 points are off the track
# Using built-in speed
# Done dist alignment for track melnikov_su3, 1204 points are off the track
# 2829
# Comparing 5 tracks
# 0:
# Track donchenko_su2
# Start time: 2019-03-20 13:28:02.710000
# End time: 2019-03-20 13:34:51.230000
# Total time: 0:06:48.520000
# Total distance travelled: 8.086 km
# Max speed: 130.60 kph
# Average speed: 70.59 kph
# Finished: True
#
#
# 1:
# Track abakumov_su1
# Start time: 2019-03-17 08:40:02.900000
# End time: 2019-03-17 08:46:59.400000
# Total time: 0:06:56.500000
# Total distance travelled: 8.086 km
# Max speed: 126.50 kph
# Average speed: 70.09 kph
# Finished: True
#
#
# 2:
# Track abakumov_su2
# Start time: 2019-03-17 10:31:03.200000
# End time: 2019-03-17 10:37:54.200000
# Total time: 0:06:51
# Total distance travelled: 8.089 km
# Max speed: 127.58 kph
# Average speed: 71.34 kph
# Finished: True
#
#
# 3:
# Track kolcov_su1
# Start time: 2019-03-20 11:35:02.640000
# End time: 2019-03-20 11:42:04.740000
# Total time: 0:07:02.100000
# Total distance travelled: 8.089 km
# Max speed: 125.60 kph
# Average speed: 68.84 kph
# Finished: True
#
#
# 4:
# Track melnikov_su3
# Start time: 2019-03-20 14:29:02.940000
# End time: 2019-03-20 14:35:45.200000
# Total time: 0:06:42.260000
# Total distance travelled: 8.086 km
# Max speed: 129.10 kph
# Average speed: 71.76 kph
# Finished: True

# %%
#viz.generate_tracks_map(comparison.aligned_tracks)
#viz.plot_distance_speed_graph(comparison.tracks)

#viz.plot_distance_speed_graph_aligned(comparison.aligned_tracks)

comparison.build_comparison_graph(TRACK_NAME, TRACK_TITLE)
